# %%
#Importing the libraries
from nsepy import get_history as gh
import datetime as dt
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from pmdarima import auto_arima 
import warnings 
from statsmodels.tsa.seasonal import seasonal_decompose 
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
import yfinance as yf

# %%
ticker = "SBIN.NS" # Assuming 'SBIN' is a stock listed on the NSE
start = dt.datetime(2013, 1, 1)
end = dt.datetime(2019, 12, 31)

# Download the historical stock prices
data = yf.download(ticker, start=start, end=end)
# Out:
# C:\Users\Om Pc\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
#print(data)

# %%
#Data Preprocessing
data['Date'] = data.index
data2 = pd.DataFrame(columns = ['Date', 'Open', 'High', 'Low', 'Close'])
data2['Date'] = data['Date']
data2['Open'] = data['Open']
data2['High'] = data['High']
data2['Low'] = data['Low']
data2['Close'] = data['Close']

# %%
print(len(data2))
# Out:
# 1720

# %%
#####################ARIMA###############################
# Ignore harmless warnings 
warnings.filterwarnings("ignore")

# %%
# Ignore harmless warnings 
warnings.filterwarnings("ignore") 
# Fit auto_arima function to Stock Market Data
stepwise_fit = auto_arima(data2['Close'], start_p = 1, start_q = 1, max_p = 3, max_q = 3, m = 12, start_P = 0, seasonal = True, d = None, D = 1, trace = True, error_action ='ignore', suppress_warnings = True, stepwise = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=8.90 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=14833.485, Time=0.14 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=11247.990, Time=1.74 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=13265.818, Time=2.59 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=14833.180, Time=0.05 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=11668.958, Time=0.21 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=11099.621, Time=6.46 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=15.66 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=5.45 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=14831.211, Time=4.12 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=11095.542, Time=8.26 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=11242.183, Time=2.01 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=17.86 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=4.33 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=11097.263, Time=10.14 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=11097.250, Time=13.84 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=11095.396, Time=8.49 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=11242.135, Time=1.84 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=inf, Time=17.46 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=6.79 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=13266.409, Time=8.51 sec
#  ARIMA(1,0,2)(2,1,0)[12] intercept   : AIC=11097.246, Time=10.86 sec
#  ARIMA(0,0,2)(2,1,0)[12] intercept   : AIC=12528.537, Time=10.87 sec
#  ARIMA(2,0,2)(2,1,0)[12] intercept   : AIC=11099.341, Time=12.00 sec
#  ARIMA(1,0,1)(2,1,0)[12]             : AIC=11093.506, Time=1.68 sec
#  ARIMA(1,0,1)(1,1,0)[12]             : AIC=11240.238, Time=0.74 sec
#  ARIMA(1,0,1)(2,1,1)[12]             : AIC=inf, Time=14.74 sec
#  ARIMA(1,0,1)(1,1,1)[12]             : AIC=inf, Time=4.91 sec
#  ARIMA(0,0,1)(2,1,0)[12]             : AIC=13266.119, Time=3.06 sec
#  ARIMA(1,0,0)(2,1,0)[12]             : AIC=11097.721, Time=1.38 sec
#  ARIMA(2,0,1)(2,1,0)[12]             : AIC=11095.358, Time=2.97 sec
#  ARIMA(1,0,2)(2,1,0)[12]             : AIC=11095.354, Time=2.32 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=14831.043, Time=0.75 sec
#  ARIMA(0,0,2)(2,1,0)[12]             : AIC=12528.285, Time=2.82 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=11093.653, Time=1.53 sec
#  ARIMA(2,0,2)(2,1,0)[12]             : AIC=11097.450, Time=2.32 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[12]
# Total fit time: 217.895 seconds

# %%
# Split data into train / test sets 
train = data2.iloc[:len(data2)-60] 
test = data2.iloc[len(data2)-60:]

# %%
# Fit a SARIMAX
model = SARIMAX(data2['Close'],  order = (0, 1, 1),  seasonal_order =(2, 1, 1, 12))

# %%
result = model.fit()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                 1720
# Model:             SARIMAX(0, 1, 1)x(2, 1, 1, 12)   Log Likelihood               -5326.666
# Date:                            Wed, 03 Apr 2024   AIC                          10663.332
# Time:                                    16:09:21   BIC                          10690.544
# Sample:                                         0   HQIC                         10673.404
#                                            - 1720
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.0332      0.021      1.553      0.120      -0.009       0.075
# ar.S.L12       0.0337      0.018      1.829      0.067      -0.002       0.070
# ar.S.L24      -0.0014      0.027     -0.052      0.959      -0.054       0.051
# ma.S.L12      -0.9999      1.107     -0.904      0.366      -3.169       1.169
# sigma2        29.0391     31.873      0.911      0.362     -33.431      91.509
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             22928.46
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.07   Skew:                             1.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start = len(train) 
end = len(train) + len(test) - 1

# %%
  
# Predictions for one-year against the test set 
predictions = result.predict(start, end, typ = 'levels').rename("Predictions")

# %%
#print(predictions)
# Out:
# Date
# 2019-10-01    270.535327
# 2019-10-03    255.059859
# 2019-10-04    253.700905
# 2019-10-07    249.942993
# 2019-10-09    248.741718
# 2019-10-10    263.222351
# 2019-10-11    254.495089
# 2019-10-14    254.039471
# 2019-10-15    254.584920
# 2019-10-16    258.665764
# 2019-10-17    255.811815
# 2019-10-18    265.328257
# 2019-10-22    269.115420
# 2019-10-23    270.322018
# 2019-10-24    275.408554
# 2019-10-25    261.912914
# 2019-10-27    282.579827
# 2019-10-29    282.372042
# 2019-10-30    280.836880
# 2019-10-31    290.117510
# 2019-11-01    313.141629
# 2019-11-04    313.501919
# 2019-11-05    314.592971
# 2019-11-06    319.453690
# 2019-11-07    317.376230
# 2019-11-08    318.209035
# 2019-11-11    315.320244
# 2019-11-13    319.006217
# 2019-11-14    306.356738
# 2019-11-15    306.811884
# 2019-11-18    323.023087
# 2019-11-19    325.958557
# 2019-11-20    330.460697
# 2019-11-21    328.800813
# 2019-11-22    331.568253
# 2019-11-25    329.095807
# 2019-11-26    336.196438
# 2019-11-27    335.246095
# 2019-11-28    343.763626
# 2019-11-29    349.000976
# 2019-12-02    341.549682
# 2019-12-03    339.896408
# 2019-12-04    336.553929
# 2019-12-05    342.237460
# 2019-12-06    335.812385
# 2019-12-09    319.605474
# 2019-12-10    316.493971
# 2019-12-11    313.510192
# 2019-12-12    312.597251
# 2019-12-13    322.337997
# 2019-12-16    332.964700
# 2019-12-17    331.458588
# 2019-12-18    332.776932
# 2019-12-19    327.592429
# 2019-12-20    328.719052
# 2019-12-23    337.978085
# 2019-12-24    331.426515
# 2019-12-26    331.356862
# 2019-12-27    329.635545
# 2019-12-30    337.448394
# Name: Predictions, dtype: float64

# %%
# plot predictions and actual values 
predictions.plot(legend = True) 
test['Close'].plot(legend = True)
# Out:
# <Axes: xlabel='Date'>

# %%
#############LSTM########################
train_set = data2.iloc[0:1333:, 1:2].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(train_set)
X_train = []
y_train = []
for i in range(60, 1333):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
#Defining the LSTM Recurrent Model
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
# Out:
# C:\Users\Om Pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
print(len(X_train))
# Out:
# 1273

# %%
#Compiling and fitting the model
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, y_train, epochs = 40, batch_size = 16)
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 0.0509
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0109
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0088
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0075
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0074
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0069
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0061
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0060
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0058
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0059
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0056
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0051
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0047
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0049
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0056
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0045
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0040
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0042
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0038
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.0041
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0038
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.0040
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0038
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0033
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0031
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0031
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0027
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0031
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0030
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0025
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0030
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.0028
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.0024
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.0020
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0027
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0027
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.0024
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0024
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0028
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0022

# %%
start = dt.datetime(2019, 10, 1)
end = dt.datetime(2019, 12, 31)

# Download the historical stock prices
data6 = yf.download(ticker, start=start, end=end)
# Out:
# C:\Users\Om Pc\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
#print(data6)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019
Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(testdata) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
# for i in range(60, 235):
#     X_test.append(inputs[i-60:i, 0])
for i in range(60, len(inputs)):
    sequence = inputs[i-60:i, 0]
    if len(sequence) == 60: # Ensure the sequence has 60 elements
        X_test.append(sequence)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(len(inputs))
# Out:
# 120

# %%
#Making predictions on the test data
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 441ms/step

# %%
#Visualizing the prediction
plt.figure()
plt.plot(real_stock_price, color = 'r', label = 'Close')
plt.plot(predicted_stock_price, color = 'b', label = 'Prediction')
#plt.plot(predictions, color = 'g', label = 'ARIMA')

plt.xlabel('Date')
plt.legend()
plt.show()

# %%
print(dataset_total)
# Out:
# Date
# 2013-01-01    240.490005
# 2013-01-02    245.000000
# 2013-01-03    246.000000
# 2013-01-04    246.000000
# 2013-01-07    249.000000
#                  ...
# 2019-12-23    335.700012
# 2019-12-24    333.200012
# 2019-12-26    333.000000
# 2019-12-27    333.399994
# 2019-12-30    337.750000
# Name: Open, Length: 1780, dtype: float64

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Assuming 'data2' contains your entire dataset
inputs = dataset_total.values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)

# Check if there are enough data points to create sequences
if len(inputs) < 1600:
    print("Not enough data points to create input sequences for prediction.")
else:
    X_pred = []  # Prepare list for input sequences

    # Create input sequences for prediction
    for i in range(1600, len(inputs) + 60):  # Extend the range by 60 steps
        start_index = max(0, i - 1600)  # Ensure start index doesn't go negative
        sequence = inputs[start_index:i, 0]
        X_pred.append(sequence)

    # Pad sequences to ensure uniform length
    X_pred = pad_sequences(X_pred, maxlen=1600, dtype='float32', padding='pre', truncating='pre')

    # Reshape for LSTM model input
    X_pred = np.reshape(X_pred, (X_pred.shape[0], -1, 1))  
    
    # Predict future values iteratively
    predicted_stock_price = []
    
    for i in range(60):
        # Predict one step ahead
        pred = regressor.predict(X_pred[i:i+1])  # Predicting only one step ahead
        predicted_stock_price.append(pred)
    
        # Concatenate pred with the last element of X_pred and reshape to match input shape
        pred = pred.reshape(1, 1, 1)
        pred = np.repeat(pred, X_pred.shape[1], axis=1)  # Repeat pred to match X_pred shape along axis 1
        X_pred = np.concatenate((X_pred, pred), axis=0)
    
    # Inverse transform to get actual values
    predicted_stock_price = sc.inverse_transform(np.array(predicted_stock_price).reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 754ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step

# %%
plt.figure()
#plt.plot(real_stock_price, color = 'r', label = 'Close')
plt.plot(predicted_stock_price, color = 'b', label = 'Prediction')
#plt.plot(predictions, color = 'g', label = 'ARIMA')

plt.xlabel('Date')
plt.legend()
plt.show()

# %%
import numpy as np

# Assuming 'predicted_data' contains the predicted data points
# 'center_line' is the y-coordinate of the center line
def invert_data(predicted_stock_price, center_line):
    inverted_data = []
    for point in predicted_stock_price:
        # Calculate the distance from the center line
        distance = point - center_line
        # Calculate the mirror image
        inverted_point = center_line - distance
        # Add the inverted point to the result
        inverted_data.append(inverted_point)
    return inverted_data

# Example usage:
#predicted_data = [352.1462, 354.17413, 355.25018, 356.73038, 356.44162, 348.8479, 352.88132, 350.20447, 352.54718, 353.51935]
center_line = np.mean(predicted_stock_price)  # Use the mean as the center line
inverted_predicted_data = invert_data(predicted_stock_price, center_line)

# %%
plt.figure()
plt.plot(real_stock_price, color = 'r', label = 'Close')
plt.plot(inverted_predicted_data, color = 'b', label = 'Prediction')
#plt.plot(predictions, color = 'g', label = 'ARIMA')

plt.xlabel('Date')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Assuming 'actual_values' and 'predicted_values' are lists or arrays of actual and predicted values
actual_values = real_stock_price
predicted_values = inverted_predicted_data

mae = mean_absolute_error(actual_values, predicted_values)
mse = mean_squared_error(actual_values, predicted_values)
rmse = np.sqrt(mse)
r2 = r2_score(actual_values, predicted_values)

# Calculate accuracy in percentage
accuracy_percentage = ((max(actual_values) - mae) / max(actual_values)) * 100

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2) Score:", r2)
print("Accuracy Percentage:", accuracy_percentage)
# Out:
# Mean Absolute Error (MAE): 11.331477864583333
# Mean Squared Error (MSE): 193.84300882583483
# Root Mean Squared Error (RMSE): 13.922751481867182
# R-squared (R2) Score: 0.8005302778683673
# Accuracy Percentage: [96.75176217]

# %%
from sklearn.metrics import mean_absolute_error

# Assuming actual_values and predicted_values are arrays or lists of actual and predicted values
actual_values = real_stock_price
predicted_values = predicted_stock_price#inverted_predicted_data

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(actual_values, predicted_values)

# Calculate accuracy in percentage
accuracy_percentage = (1 - (mae / np.max(actual_values))) * 100

print("Accuracy:", accuracy_percentage, "%")
# Out:
# Accuracy: 84.18334154629567 %

# %%
from sklearn.metrics import mean_absolute_error

# Assuming actual_values and predicted_values are arrays or lists of actual and predicted values
actual_values = np.array([[272.75], [254.], [258.5], [251.5], [250.1000061], [258.], [256.20001221], [256.95001221], [256.45001221], [259.29998779], [256.3999939], [264.3999939], [270.3999939], [270.75], [276.], [265.79998779], [284.95001221], [283.1499939], [283.], [293.3500061], [312.3999939], [316.], [313.8999939], [318.95001221], [318.25], [316.20001221], [314.70001221], [316.04998779], [306.95001221], [312.], [324.], [325.79998779], [332.], [329.25], [331.45001221], [329.], [338.], [335.95001221], [346.8500061], [348.8500061], [343.8999939], [341.], [334.1000061], [343.], [336.70001221], [318.95001221], [317.20001221], [311.20001221], [314.], [325.20001221], [335.95001221], [333.25], [335.], [327.3500061], [330.3500061], [335.70001221], [333.20001221], [333.], [333.3999939], [337.75]])

predicted_values = np.array([[269.9116], [268.13873], [265.77136], [263.5487], [263.90884], [272.91556], [272.44824], [270.8785], [267.37146], [265.74707], [269.53326], [268.4025], [262.1271], [264.17484], [271.7662], [277.3935], [283.26492], [284.79697], [284.5202], [282.4826], [281.70078], [292.6072], [296.634], [303.71396], [315.3542], [321.99408], [321.63306], [324.9416], [326.00806], [328.367], [333.09418], [335.50134], [334.16983], [334.44516], [336.48602], [341.22516], [349.09772], [346.51706], [341.4954], [337.96985], [338.621], [343.53644], [349.1593], [353.10526], [352.3743], [349.85455], [348.6563], [347.02594], [342.50192], [339.82056], [338.1791], [338.99146], [343.40744], [345.81033], [347.9566], [334.67624], [318.38043], [320.1582], [333.10117], [342.29376]])

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(actual_values, predicted_values)

# Calculate accuracy percentage
accuracy_percentage = (1 - (mae / np.max(actual_values))) * 100

print("Accuracy:", accuracy_percentage, "%")
# Out:
# Accuracy: 96.7517623307465 %

# %%
from sklearn.metrics import mean_absolute_error

# Convert the predicted and actual values to numpy arrays
predicted_values = inverted_predicted_data
actual_values = real_stock_price

# Calculate the absolute error
absolute_errors = np.abs(predicted_values - actual_values)

# Calculate the accuracy percentage for each predicted value
accuracies = (1 - absolute_errors / actual_values) * 100

# Print the actual values, predicted values, their difference, and accuracy
for i, (actual, predicted, diff, accuracy) in enumerate(zip(actual_values, predicted_values, absolute_errors, accuracies)):
    print(f"Value {i + 1}:")
    print(f"  Actual: {actual[0]}")
    print(f"  Predicted: {predicted[0]}")
    print(f"  Difference: {diff[0]}")
    print(f"  Accuracy: {accuracy[0]:.2f}%")
# Out:
# Value 1:
#   Actual: 272.75
#   Predicted: 269.9115905761719
#   Difference: 2.838409423828125
#   Accuracy: 98.96%
# Value 2:
#   Actual: 254.0
#   Predicted: 268.13873291015625
#   Difference: 14.13873291015625
#   Accuracy: 94.43%
# Value 3:
#   Actual: 258.5
#   Predicted: 265.7713623046875
#   Difference: 7.2713623046875
#   Accuracy: 97.19%
# Value 4:
#   Actual: 251.5
#   Predicted: 263.5487060546875
#   Difference: 12.0487060546875
#   Accuracy: 95.21%
# Value 5:
#   Actual: 250.10000610351562
#   Predicted: 263.9088439941406
#   Difference: 13.808837890625
#   Accuracy: 94.48%
# Value 6:
#   Actual: 258.0
#   Predicted: 272.9155578613281
#   Difference: 14.915557861328125
#   Accuracy: 94.22%
# Value 7:
#   Actual: 256.20001220703125
#   Predicted: 272.4482421875
#   Difference: 16.24822998046875
#   Accuracy: 93.66%
# Value 8:
#   Actual: 256.95001220703125
#   Predicted: 270.8785095214844
#   Difference: 13.928497314453125
#   Accuracy: 94.58%
# Value 9:
#   Actual: 256.45001220703125
#   Predicted: 267.3714599609375
#   Difference: 10.92144775390625
#   Accuracy: 95.74%
# Value 10:
#   Actual: 259.29998779296875
#   Predicted: 265.7470703125
#   Difference: 6.44708251953125
#   Accuracy: 97.51%
# Value 11:
#   Actual: 256.3999938964844
#   Predicted: 269.53326416015625
#   Difference: 13.133270263671875
#   Accuracy: 94.88%
# Value 12:
#   Actual: 264.3999938964844
#   Predicted: 268.4024963378906
#   Difference: 4.00250244140625
#   Accuracy: 98.49%
# Value 13:
#   Actual: 270.3999938964844
#   Predicted: 262.1271057128906
#   Difference: 8.27288818359375
#   Accuracy: 96.94%
# Value 14:
#   Actual: 270.75
#   Predicted: 264.1748352050781
#   Difference: 6.575164794921875
#   Accuracy: 97.57%
# Value 15:
#   Actual: 276.0
